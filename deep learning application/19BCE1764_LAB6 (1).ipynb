# %% [markdown]
# # Learn Keras for Deep Neural Networks
# ## An Introduction to Deep Learning and Keras

# %% [markdown]
# A sneak peek in the Keras Framework

# %%
import os
import logging

import pandas as pd
import tensorflow.keras as keras

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# Log setting
logging.basicConfig(format="%(asctime)s %(levelname)s %(message)s", datefmt="%H:%M:%S", level=logging.INFO)

# Change display.max_rows to show all features.
pd.set_option("display.max_rows", 85)

# %%
df_train = pd.read_csv(('/content/drive/MyDrive/datasets/train_MachineLearningCVE.csv'), skipinitialspace=True)
logging.info("Class distribution\n{}".format(df_train.Label.value_counts()))
df_test = pd.read_csv(('/content/drive/MyDrive/datasets/test_MachineLearningCVE.csv'), skipinitialspace=True)
logging.info("Class distribution\n{}".format(df_test.Label.value_counts()))

# %%
df_train.Label.unique()
df_test.Label.unique()
df = pd.concat([df_train, df_test], axis=0, copy=True)
df.Label.unique()
# Out:
# array([ 0, 10,  4,  7,  3,  5,  6, 11,  1, 12, 14,  9,  8, 13,  2])

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

def preprocessing(df: pd.DataFrame) -> (np.ndarray, np.ndarray):
    # Shuffle the dataset
    df = df.sample(frac=1)

    # Split features and labels
    x = df.iloc[:, df.columns != 'Label']
    y = df[['Label']].to_numpy()

    # Scale the features between 0 ~ 1
    scaler = MinMaxScaler()
    x = scaler.fit_transform(x)

    return x, y

x, y = preprocessing(df)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x, y, train_size=0.7, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1981520, 78)
# (849223, 78)
# (1981520, 1)
# (849223, 1)

# %%
logging.info("Class distribution\n{}".format(df.Label.value_counts()))

# %%
#Import required packages
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %%
# Getting the data ready
# Generate train dummy data for 1000 Students and dummy test for 500
#Columns :Age, Hours of Study & Avg Previous test scores
np.random.seed(2018)
tr_data, te_data = x,y
#Generate dummy results for 1000 students : Whether Passed (1) or Failed (0)
labels = np.random.randint(2, size=(1000, 1))

# %%
print(tr_data.shape)
train_data = tr_data.reshape(220797954,1)
train_data = train_data[1:3001]
train_data = train_data.reshape(1000,3)
print(train_data.shape)
print(labels.shape)
# Out:
# (2830743, 78)
# (1000, 3)
# (1000, 1)

# %%
print(te_data.shape)
test_data = te_data[1:3001]
test_data = test_data.reshape(1000,3);
print(test_data.shape)
# Out:
# (2830743, 1)
# (1000, 3)

# %%
#Defining the model structure with the required layers, # of neurons, activation function and optimizers
model = Sequential()
model.add(Dense(5, input_dim=3, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 20
#
#  dense_1 (Dense)             (None, 4)                 24
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model and make predictions
model.fit(train_data, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 2ms/step - loss: 0.6976 - accuracy: 0.5040
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6963 - accuracy: 0.5190
# Epoch 3/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6954 - accuracy: 0.5120
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6947 - accuracy: 0.5180
# Epoch 5/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.4850
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.5070
# Epoch 7/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5150
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5130
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5160
# Epoch 10/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5160

# %%
#Make predictions from the trained model
predictions = model.predict(test_data)

# %%
predictions
# Out:
# array([[0.49773353],
#        [0.99556875],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.96227753],
#        [0.8617834 ],
#        [0.22142348],
#        [0.8617834 ],
#        [0.99050933],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.687667  ],
#        [0.8617834 ],
#        [0.99286425],
#        [0.9887357 ],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.8984884 ],
#        [0.14902857],
#        [0.95659083],
#        [0.49773353],
#        [0.8984884 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.47918898],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.8469171 ],
#        [0.8984884 ],
#        [0.49773353],
#        [0.687667  ],
#        [0.39844453],
#        [0.8984884 ],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.25441146],
#        [0.8617834 ],
#        [0.49773353],
#        [0.39844453],
#        [0.9410012 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.64629596],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.99050933],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.45205638],
#        [0.99050933],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.3744535 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.99050933],
#        [0.49773353],
#        [0.47918898],
#        [0.49773353],
#        [0.9088608 ],
#        [0.45205638],
#        [0.8617834 ],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.9887357 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.8469171 ],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.32201588],
#        [0.99050933],
#        [0.687667  ],
#        [0.49773353],
#        [0.22142345],
#        [0.49773353],
#        [0.8469171 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.14902857],
#        [0.8984884 ],
#        [0.32201588],
#        [0.92791855],
#        [0.49773353],
#        [0.35933843],
#        [0.14902857],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.9887357 ],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902854],
#        [0.49773353],
#        [0.8617834 ],
#        [0.9887357 ],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.8617834 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.22384784],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.92791855],
#        [0.47918898],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.7090837 ],
#        [0.47962397],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.49773353],
#        [0.47918898],
#        [0.8469171 ],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.687667  ],
#        [0.9597833 ],
#        [0.49773353],
#        [0.5231116 ],
#        [0.8469171 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.99050933],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.22142348],
#        [0.49773353],
#        [0.32201588],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.99292934],
#        [0.8617834 ],
#        [0.9887357 ],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.7090837 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.32201588],
#        [0.32201588],
#        [0.8469171 ],
#        [0.32201588],
#        [0.49773353],
#        [0.32201588],
#        [0.92791855],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.3263198 ],
#        [0.32201588],
#        [0.8617834 ],
#        [0.49773353],
#        [0.55151147],
#        [0.32201588],
#        [0.9887357 ],
#        [0.32201588],
#        [0.9887357 ],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.99746716],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.7678257 ],
#        [0.49773353],
#        [0.49773353],
#        [0.79585075],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.22142348],
#        [0.9887357 ],
#        [0.14902857],
#        [0.14902857],
#        [0.49773353],
#        [0.9887357 ],
#        [0.9088608 ],
#        [0.49773353],
#        [0.49773353],
#        [0.14902854],
#        [0.8984884 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.22142348],
#        [0.49773353],
#        [0.99050933],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9996731 ],
#        [0.14902857],
#        [0.99050933],
#        [0.49773353],
#        [0.19716299],
#        [0.3744535 ],
#        [0.8617834 ],
#        [0.7090837 ],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.9887357 ],
#        [0.7090837 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.99050933],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.9996731 ],
#        [0.9887357 ],
#        [0.7678257 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.98285395],
#        [0.14902857],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.5231116 ],
#        [0.49773353],
#        [0.99050933],
#        [0.32201588],
#        [0.8469171 ],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.99556875],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.687667  ],
#        [0.98285395],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.7090837 ],
#        [0.14902854],
#        [0.14902857],
#        [0.7090837 ],
#        [0.49773353],
#        [0.8469171 ],
#        [0.32201588],
#        [0.49773353],
#        [0.9887357 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.14902857],
#        [0.49773353],
#        [0.7090837 ],
#        [0.12914643],
#        [0.62403274],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.32201588],
#        [0.7090837 ],
#        [0.14902857],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.687667  ],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.22384784],
#        [0.62403274],
#        [0.3744535 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.39844453],
#        [0.8398036 ],
#        [0.99050933],
#        [0.9887357 ],
#        [0.99050933],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.14902857],
#        [0.32201588],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.17105308],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.9887357 ],
#        [0.8617834 ],
#        [0.7090837 ],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902854],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.8617834 ],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.8469171 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.687667  ],
#        [0.9887357 ],
#        [0.9597833 ],
#        [0.49634802],
#        [0.49773353],
#        [0.98285395],
#        [0.49773353],
#        [0.68766695],
#        [0.9597833 ],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.22384784],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.46054488],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.46639627],
#        [0.8617834 ],
#        [0.99050933],
#        [0.47788423],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.99746716],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.3744535 ],
#        [0.32201588],
#        [0.8469171 ],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.8617834 ],
#        [0.8617834 ],
#        [0.99050933],
#        [0.99292934],
#        [0.9887357 ],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.92791855],
#        [0.8469171 ],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.45205638],
#        [0.6462959 ],
#        [0.8617834 ],
#        [0.8984884 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.35933843],
#        [0.27275568],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.92791855],
#        [0.9597833 ],
#        [0.35910368],
#        [0.4187061 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.9940449 ],
#        [0.49773353],
#        [0.99050933],
#        [0.99050933],
#        [0.7090837 ],
#        [0.49773353],
#        [0.7090837 ],
#        [0.39844453],
#        [0.2868342 ],
#        [0.34220093],
#        [0.5231116 ],
#        [0.39844453],
#        [0.49773353],
#        [0.9597833 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.45205638],
#        [0.49773353],
#        [0.687667  ],
#        [0.8469171 ],
#        [0.8469171 ],
#        [0.9887357 ],
#        [0.32201588],
#        [0.49773353],
#        [0.23236516],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.92791855],
#        [0.47918898],
#        [0.49773353],
#        [0.8617834 ],
#        [0.99050933],
#        [0.687667  ],
#        [0.687667  ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.687667  ],
#        [0.8469171 ],
#        [0.795891  ],
#        [0.49773353],
#        [0.8469171 ],
#        [0.99050933],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.79585075],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.25441146],
#        [0.98285395],
#        [0.8617834 ],
#        [0.22142348],
#        [0.8469171 ],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.8617834 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.7090837 ],
#        [0.49773353],
#        [0.32201588],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.8469171 ],
#        [0.9887357 ],
#        [0.49773353],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.32201588],
#        [0.39844453],
#        [0.49773353],
#        [0.9887357 ],
#        [0.8617834 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.35933843],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.39844456],
#        [0.14902854],
#        [0.39844453],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.49773353],
#        [0.98285395],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.17105308],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.49773353],
#        [0.14902857],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.25441146],
#        [0.7090837 ],
#        [0.99050933],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.99050933],
#        [0.91415954],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.9887357 ],
#        [0.68766695],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.19716299],
#        [0.99050933],
#        [0.687667  ],
#        [0.795891  ],
#        [0.49773353],
#        [0.49773353],
#        [0.8469171 ],
#        [0.687667  ],
#        [0.49773353],
#        [0.49773353],
#        [0.47962397],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.517809  ],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.8481091 ],
#        [0.99050933],
#        [0.14902857],
#        [0.49773353],
#        [0.8469171 ],
#        [0.49773353],
#        [0.8617834 ],
#        [0.795891  ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.14902857],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.39844453],
#        [0.99050933],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.99556875],
#        [0.8976441 ],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.25441146],
#        [0.22142348],
#        [0.79585075],
#        [0.32201588],
#        [0.8469171 ],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.8469171 ],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.9799656 ],
#        [0.49773353],
#        [0.49773353],
#        [0.7090837 ],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.8617834 ],
#        [0.49773353],
#        [0.39844453],
#        [0.9597833 ],
#        [0.39838657],
#        [0.8469171 ],
#        [0.49773353],
#        [0.14902857],
#        [0.49773353],
#        [0.14902857],
#        [0.9887357 ],
#        [0.49773353],
#        [0.49773353],
#        [0.14902857],
#        [0.39838657],
#        [0.3593384 ],
#        [0.6349814 ],
#        [0.17105308],
#        [0.49773353],
#        [0.49773353],
#        [0.49773353],
#        [0.8617834 ],
#        [0.99050933],
#        [0.45205635]], dtype=float32)

# %%
#Import required packages
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# Getting the data ready
# Generate train dummy data for 1000 Students and dummy test for 500
#Columns :Age, Hours of Study & Avg Previous test scores
np.random.seed(2018)
# train_data, test_data = np.random.random((1000, 3)), np.random.random((500, 3))
#Generate dummy results for 1000 students : Whether Passed (1) or Failed (0)
# labels = np.random.randint(2, size=(1000, 1))

#Defining the model structure with the required layers, # of neurons, activation function and optimizers
model = Sequential()
model.add(Dense(5, input_dim=3, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#Train the model and make predictions
model.fit(train_data, labels, epochs=10, batch_size=32)

#Make predictions from the trained model
predictions = model.predict(test_data)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 2ms/step - loss: 0.6933 - accuracy: 0.4960
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5020
# Epoch 3/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5020
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5010
# Epoch 5/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5160
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5100
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5140
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.5130
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5090
# Epoch 10/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.5160

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation

np.random.seed(2018)

# Generate dummy training dataset
x_train = np.random.random((6000,10))
x_train = tr_data.reshape(220797954,1)
x_tr = x_train[1:60001]
x_train = x_tr.reshape(6000,10)
y_train = np.random.randint(2, size=(6000, 1))

# Generate dummy validation dataset
x_val = np.random.random((2000,10))
y_val = np.random.randint(2, size=(2000, 1))

# Generate dummy test dataset
x_test = np.random.random((2000,10))
x_t = te_data[1:20001]
x_test = x_t.reshape(2000,10)
y_test = np.random.randint(2, size=(2000, 1))

#Define the model architecture
model = Sequential()
model.add(Dense(64, input_dim=10,activation = "relu")) #Layer 1
model.add(Dense(32,activation = "relu"))               #Layer 2
model.add(Dense(16,activation = "relu"))               #Layer 3
model.add(Dense(8,activation = "relu"))                #Layer 4
model.add(Dense(4,activation = "relu"))                #Layer 5
model.add(Dense(1,activation = "sigmoid"))             #Output Layer

#Configure the model
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

#Train the model
model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 94/94 [==============================] - 1s 5ms/step - loss: 0.6932 - accuracy: 0.4945 - val_loss: 0.6929 - val_accuracy: 0.5135
# Epoch 2/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.4998 - val_loss: 0.6950 - val_accuracy: 0.5010
# Epoch 3/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5023 - val_loss: 0.6958 - val_accuracy: 0.5020
# Epoch 4/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5157 - val_loss: 0.6987 - val_accuracy: 0.5025
# Epoch 5/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5030 - val_loss: 0.7000 - val_accuracy: 0.5020
# Epoch 6/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5167 - val_loss: 0.7044 - val_accuracy: 0.5010
# Epoch 7/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5100 - val_loss: 0.7062 - val_accuracy: 0.5015
# Epoch 8/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5153 - val_loss: 0.7012 - val_accuracy: 0.5095
# Epoch 9/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6924 - accuracy: 0.5122 - val_loss: 0.6994 - val_accuracy: 0.5045
# Epoch 10/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.5123 - val_loss: 0.7060 - val_accuracy: 0.5020
# Epoch 11/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5142 - val_loss: 0.7091 - val_accuracy: 0.5005
# Epoch 12/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.5133 - val_loss: 0.7128 - val_accuracy: 0.5005
# Epoch 13/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6917 - accuracy: 0.5145 - val_loss: 0.6999 - val_accuracy: 0.5105
# Epoch 14/50
# 94/94 [==============================] - 0s 4ms/step - loss: 0.6921 - accuracy: 0.5162 - val_loss: 0.7165 - val_accuracy: 0.5000
# Epoch 15/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6917 - accuracy: 0.5203 - val_loss: 0.7144 - val_accuracy: 0.5000
# Epoch 16/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6915 - accuracy: 0.5178 - val_loss: 0.7116 - val_accuracy: 0.5015
# Epoch 17/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6912 - accuracy: 0.5217 - val_loss: 0.7249 - val_accuracy: 0.5005
# Epoch 18/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6912 - accuracy: 0.5145 - val_loss: 0.7268 - val_accuracy: 0.5020
# Epoch 19/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6909 - accuracy: 0.5225 - val_loss: 0.7301 - val_accuracy: 0.5010
# Epoch 20/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6910 - accuracy: 0.5215 - val_loss: 0.7219 - val_accuracy: 0.4990
# Epoch 21/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6906 - accuracy: 0.5240 - val_loss: 0.7294 - val_accuracy: 0.5040
# Epoch 22/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6904 - accuracy: 0.5205 - val_loss: 0.7285 - val_accuracy: 0.5020
# Epoch 23/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.6895 - accuracy: 0.5177 - val_loss: 0.7211 - val_accuracy: 0.4970
# Epoch 24/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.5257 - val_loss: 0.7262 - val_accuracy: 0.4980
# Epoch 25/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5240 - val_loss: 0.7495 - val_accuracy: 0.5030
# Epoch 26/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.5270 - val_loss: 0.7240 - val_accuracy: 0.4870
# Epoch 27/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.6889 - accuracy: 0.5228 - val_loss: 0.7378 - val_accuracy: 0.5015
# Epoch 28/50
# 94/94 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5303 - val_loss: 0.7493 - val_accuracy: 0.4950
# Epoch 29/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6881 - accuracy: 0.5313 - val_loss: 0.7581 - val_accuracy: 0.5040
# Epoch 30/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.5302 - val_loss: 0.7602 - val_accuracy: 0.4990
# Epoch 31/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6875 - accuracy: 0.5302 - val_loss: 0.7626 - val_accuracy: 0.4980
# Epoch 32/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5300 - val_loss: 0.7501 - val_accuracy: 0.4900
# Epoch 33/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5342 - val_loss: 0.7619 - val_accuracy: 0.4935
# Epoch 34/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.5338 - val_loss: 0.7970 - val_accuracy: 0.4995
# Epoch 35/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.5330 - val_loss: 0.7990 - val_accuracy: 0.5030
# Epoch 36/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.5348 - val_loss: 0.7663 - val_accuracy: 0.4915
# Epoch 37/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5365 - val_loss: 0.8009 - val_accuracy: 0.4985
# Epoch 38/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6864 - accuracy: 0.5352 - val_loss: 0.8033 - val_accuracy: 0.4965
# Epoch 39/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.5337 - val_loss: 0.7923 - val_accuracy: 0.4935
# Epoch 40/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6850 - accuracy: 0.5373 - val_loss: 0.8173 - val_accuracy: 0.5020
# Epoch 41/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6854 - accuracy: 0.5385 - val_loss: 0.8215 - val_accuracy: 0.5045
# Epoch 42/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.5340 - val_loss: 0.7826 - val_accuracy: 0.4940
# Epoch 43/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.5367 - val_loss: 0.7739 - val_accuracy: 0.4890
# Epoch 44/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6844 - accuracy: 0.5363 - val_loss: 0.7755 - val_accuracy: 0.4945
# Epoch 45/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6845 - accuracy: 0.5395 - val_loss: 0.7775 - val_accuracy: 0.4920
# Epoch 46/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.5372 - val_loss: 0.7959 - val_accuracy: 0.4885
# Epoch 47/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.5400 - val_loss: 0.8163 - val_accuracy: 0.5050
# Epoch 48/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6839 - accuracy: 0.5373 - val_loss: 0.8173 - val_accuracy: 0.4975
# Epoch 49/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.5367 - val_loss: 0.8087 - val_accuracy: 0.4835
# Epoch 50/50
# 94/94 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5382 - val_loss: 0.8710 - val_accuracy: 0.4840

# %%
#Make predictions from the trained model
predictions = model.predict(x_test)

# %%
predictions
# Out:
# array([[2.3245035e-10],
#        [4.7659242e-01],
#        [3.8888156e-03],
#        ...,
#        [5.5876434e-01],
#        [4.1089683e-07],
#        [4.6738625e-01]], dtype=float32)
